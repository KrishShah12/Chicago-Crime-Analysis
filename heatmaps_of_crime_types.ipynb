# %%
#importing numpy for mathematical operation
import numpy as np

#importing the pandas for handling the data
import pandas as pd

#importing matplotlib for plotting purpose
import matplotlib.pyplot as plt

#importing seaborn for drawing the countplot and barplot
import seaborn as sns

# %%
crimes = pd.read_csv('/content/drive/MyDrive/Regression/final_crimes_data_1.csv')

# %%
crimes.head()
# Out:
#          ID Case Number                 Date                 Block  \
# 0  13230310    JG447808  2018-01-01 00:00:00   041XX N ASHLAND AVE
# 1  13235163    JG453401  2018-01-01 00:00:00     027XX N MANGO AVE
# 2  11848137    JC457303  2018-01-01 00:00:00  081XX S EBERHART AVE
# 3  11768997    JC362338  2018-01-01 00:00:00   001XX N ASHLAND AVE
# 4  12057588    JD240441  2018-01-01 00:00:00     048XX N AVERS AVE
#
#                  Primary Type  \
# 0          DECEPTIVE PRACTICE
# 1  OFFENSE INVOLVING CHILDREN
# 2     CRIMINAL SEXUAL ASSAULT
# 3                 SEX OFFENSE
# 4  OFFENSE INVOLVING CHILDREN
#
#                                          Description Location Description  \
# 0                FINANCIAL IDENTITY THEFT OVER $ 300            APARTMENT
# 1  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER            RESIDENCE
# 2                                 AGGRAVATED - OTHER            RESIDENCE
# 3                          AGG CRIMINAL SEXUAL ABUSE            RESIDENCE
# 4             CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER            APARTMENT
#
#    Arrest  Domestic  Beat  District  Ward  Community Area  Year        date  \
# 0       0         0  1912        19  47.0             6.0  2018  2018-01-01
# 1       0         1  2514        25  30.0            19.0  2018  2018-01-01
# 2       1         0   631         6   6.0            44.0  2018  2018-01-01
# 3       0         1  1224        12  27.0            28.0  2018  2018-01-01
# 4       0         1  1712        17  35.0            14.0  2018  2018-01-01
#
#        time  Weekday
# 0  00:00:00        0
# 1  00:00:00        0
# 2  00:00:00        0
# 3  00:00:00        0
# 4  00:00:00        0

# %%
crimes.shape
# Out:
# (1191586, 17)

# %%
df = crimes.copy()
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df.set_index('Date', inplace=True)
df.head()
# Out:
#                   ID Case Number                 Block  \
# Date
# 2018-01-01  13230310    JG447808   041XX N ASHLAND AVE
# 2018-01-01  13235163    JG453401     027XX N MANGO AVE
# 2018-01-01  11848137    JC457303  081XX S EBERHART AVE
# 2018-01-01  11768997    JC362338   001XX N ASHLAND AVE
# 2018-01-01  12057588    JD240441     048XX N AVERS AVE
#
#                           Primary Type  \
# Date
# 2018-01-01          DECEPTIVE PRACTICE
# 2018-01-01  OFFENSE INVOLVING CHILDREN
# 2018-01-01     CRIMINAL SEXUAL ASSAULT
# 2018-01-01                 SEX OFFENSE
# 2018-01-01  OFFENSE INVOLVING CHILDREN
#
#                                                   Description  \
# Date
# 2018-01-01                FINANCIAL IDENTITY THEFT OVER $ 300
# 2018-01-01  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 2018-01-01                                 AGGRAVATED - OTHER
# 2018-01-01                          AGG CRIMINAL SEXUAL ABUSE
# 2018-01-01             CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
#
#            Location Description  Arrest  Domestic  Beat  District  Ward  \
# Date
# 2018-01-01            APARTMENT       0         0  1912        19  47.0
# 2018-01-01            RESIDENCE       0         1  2514        25  30.0
# 2018-01-01            RESIDENCE       1         0   631         6   6.0
# 2018-01-01            RESIDENCE       0         1  1224        12  27.0
# 2018-01-01            APARTMENT       0         1  1712        17  35.0
#
#             Community Area  Year        date      time  Weekday  Month
# Date
# 2018-01-01             6.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            19.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            44.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            28.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            14.0  2018  2018-01-01  00:00:00        0      1

# %%
df['Month'].value_counts()
# Out:
# 7     111372
# 8     110733
# 10    105641
# 6     105211
# 9     105171
# 5     104029
# 12     96599
# 11     95583
# 1      93134
# 3      92997
# 4      88750
# 2      82366
# Name: Month, dtype: int64

# %%
df.isna().sum()
# Out:
# ID                         0
# Case Number                0
# Block                      0
# Primary Type               0
# Description                0
# Location Description    6108
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                      49
# Community Area             2
# Year                       0
# date                       0
# time                       0
# Weekday                    0
# Month                      0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# ID                      0
# Case Number             0
# Block                   0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# Year                    0
# date                    0
# time                    0
# Weekday                 0
# Month                   0
# dtype: int64

# %%
df.shape
# Out:
# (1185429, 17)

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:00',
#                '2018-01-01 00:00:00', '2018-01-01 00:00:00',
#                '2018-01-01 00:00:00', '2018-01-01 00:00:00',
#                '2018-01-01 00:00:00', '2018-01-01 00:00:00',
#                '2018-01-01 00:00:00', '2018-01-01 00:00:00',
#                ...
#                '2023-01-01 23:30:00', '2023-01-01 23:30:00',
#                '2023-01-01 23:30:00', '2023-01-01 23:30:00',
#                '2023-01-01 23:30:00', '2023-01-01 23:33:00',
#                '2023-01-01 23:49:00', '2023-01-01 23:49:00',
#                '2023-01-01 23:49:00', '2023-01-01 23:59:00'],
#               dtype='datetime64[ns]', name='Date', length=1185429, freq=None)

# %%
crimes_count_date = df.pivot_table('ID', aggfunc=np.size, columns='Primary Type', index=df.index, fill_value=0)
crimes_count_date
# Out:
# Primary Type         ARSON  ASSAULT  BATTERY  BURGLARY  \
# Date
# 2018-01-01 00:00:00      0        2        5         1
# 2018-01-01 00:01:00      0        0        3         2
# 2018-01-01 00:05:00      0        0        1         0
# 2018-01-01 00:08:00      0        0        0         0
# 2018-01-01 00:09:00      0        0        1         0
# ...                    ...      ...      ...       ...
# 2023-01-01 23:25:00      0        0        0         0
# 2023-01-01 23:30:00      0        2        3         0
# 2023-01-01 23:33:00      0        0        0         0
# 2023-01-01 23:49:00      0        0        0         0
# 2023-01-01 23:59:00      0        0        1         0
#
# Primary Type         CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Date
# 2018-01-01 00:00:00                                  0                    4
# 2018-01-01 00:01:00                                  0                    2
# 2018-01-01 00:05:00                                  0                    0
# 2018-01-01 00:08:00                                  0                    0
# 2018-01-01 00:09:00                                  0                    0
# ...                                                ...                  ...
# 2023-01-01 23:25:00                                  0                    0
# 2023-01-01 23:30:00                                  0                    0
# 2023-01-01 23:33:00                                  0                    0
# 2023-01-01 23:49:00                                  0                    0
# 2023-01-01 23:59:00                                  0                    0
#
# Primary Type         CRIMINAL DAMAGE  CRIMINAL SEXUAL ASSAULT  \
# Date
# 2018-01-01 00:00:00                4                       10
# 2018-01-01 00:01:00                5                        3
# 2018-01-01 00:05:00                1                        0
# 2018-01-01 00:08:00                1                        0
# 2018-01-01 00:09:00                0                        0
# ...                              ...                      ...
# 2023-01-01 23:25:00                0                        0
# 2023-01-01 23:30:00                0                        0
# 2023-01-01 23:33:00                0                        0
# 2023-01-01 23:49:00                0                        0
# 2023-01-01 23:59:00                0                        0
#
# Primary Type         CRIMINAL TRESPASS  DECEPTIVE PRACTICE  ...  \
# Date                                                        ...
# 2018-01-01 00:00:00                  1                  36  ...
# 2018-01-01 00:01:00                  1                   9  ...
# 2018-01-01 00:05:00                  0                   0  ...
# 2018-01-01 00:08:00                  0                   0  ...
# 2018-01-01 00:09:00                  0                   0  ...
# ...                                ...                 ...  ...
# 2023-01-01 23:25:00                  0                   0  ...
# 2023-01-01 23:30:00                  0                   0  ...
# 2023-01-01 23:33:00                  0                   0  ...
# 2023-01-01 23:49:00                  0                   0  ...
# 2023-01-01 23:59:00                  0                   0  ...
#
# Primary Type         OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# Date
# 2018-01-01 00:00:00              8             0                 0
# 2018-01-01 00:01:00              3             0                 0
# 2018-01-01 00:05:00              0             0                 0
# 2018-01-01 00:08:00              0             0                 0
# 2018-01-01 00:09:00              0             0                 0
# ...                            ...           ...               ...
# 2023-01-01 23:25:00              0             0                 0
# 2023-01-01 23:30:00              0             0                 0
# 2023-01-01 23:33:00              0             0                 0
# 2023-01-01 23:49:00              1             0                 0
# 2023-01-01 23:59:00              0             0                 0
#
# Primary Type         PUBLIC PEACE VIOLATION  RITUALISM  ROBBERY  SEX OFFENSE  \
# Date
# 2018-01-01 00:00:00                       0          0        0           18
# 2018-01-01 00:01:00                       0          0        0           19
# 2018-01-01 00:05:00                       0          0        0            0
# 2018-01-01 00:08:00                       0          0        0            0
# 2018-01-01 00:09:00                       0          0        0            0
# ...                                     ...        ...      ...          ...
# 2023-01-01 23:25:00                       0          0        0            0
# 2023-01-01 23:30:00                       0          0        0            0
# 2023-01-01 23:33:00                       1          0        0            0
# 2023-01-01 23:49:00                       0          0        0            0
# 2023-01-01 23:59:00                       0          0        0            0
#
# Primary Type         STALKING  THEFT  WEAPONS VIOLATION
# Date
# 2018-01-01 00:00:00         0      8                  0
# 2018-01-01 00:01:00         0      7                  0
# 2018-01-01 00:05:00         0      0                  1
# 2018-01-01 00:08:00         0      0                  0
# 2018-01-01 00:09:00         0      0                  1
# ...                       ...    ...                ...
# 2023-01-01 23:25:00         0      0                  1
# 2023-01-01 23:30:00         0      0                  0
# 2023-01-01 23:33:00         0      0                  0
# 2023-01-01 23:49:00         0      1                  1
# 2023-01-01 23:59:00         0      0                  0
#
# [576390 rows x 34 columns]

# %%
df['Primary Type'].value_counts()
# Out:
# THEFT                                264836
# BATTERY                              222319
# CRIMINAL DAMAGE                      131840
# ASSAULT                              100471
# DECEPTIVE PRACTICE                    85794
# OTHER OFFENSE                         75126
# MOTOR VEHICLE THEFT                   61055
# NARCOTICS                             46236
# BURGLARY                              44317
# ROBBERY                               42421
# WEAPONS VIOLATION                     38042
# CRIMINAL TRESPASS                     25537
# OFFENSE INVOLVING CHILDREN            10661
# SEX OFFENSE                            5912
# PUBLIC PEACE VIOLATION                 5477
# CRIMINAL SEXUAL ASSAULT                5316
# INTERFERENCE WITH PUBLIC OFFICER       4214
# HOMICIDE                               3447
# CRIM SEXUAL ASSAULT                    2380
# ARSON                                  2288
# PROSTITUTION                           2054
# STALKING                               1457
# LIQUOR LAW VIOLATION                   1031
# CONCEALED CARRY LICENSE VIOLATION       860
# INTIMIDATION                            798
# KIDNAPPING                              670
# GAMBLING                                390
# OBSCENITY                               302
# HUMAN TRAFFICKING                        58
# NON-CRIMINAL                             49
# PUBLIC INDECENCY                         43
# OTHER NARCOTIC VIOLATION                 24
# NON-CRIMINAL (SUBJECT SPECIFIED)          3
# RITUALISM                                 1
# Name: Primary Type, dtype: int64

# %% [markdown]
# ## Categorizing crimes into 12 broader classifications based on the US Topological Crime Classification.

# %%
crime_mapping = {
    'THEFT': ['THEFT', 'MOTOR VEHICLE THEFT', 'BURGLARY', 'ROBBERY'],
    'VIOLENCE': ['BATTERY', 'ASSAULT', 'HOMICIDE', 'CRIMINAL SEXUAL ASSAULT', 'KIDNAPPING', 'CRIM SEXUAL ASSAULT'],
    'PROPERTY DAMAGE': ['CRIMINAL DAMAGE', 'ARSON'],
    'DECEPTIVE PRACTICE': ['DECEPTIVE PRACTICE'],
    'DRUGS RELATED': ['NARCOTICS', 'OTHER NARCOTIC VIOLATION'],
    'WEAPONS VIOLATION': ['WEAPONS VIOLATION'],
    'TRESPASSING': ['CRIMINAL TRESPASS'],
    'OFFENSE INVOLVING CHILDREN': ['OFFENSE INVOLVING CHILDREN'],
    'SEX OFFENSE': ['SEX OFFENSE', 'PROSTITUTION'],
    'PUBLIC ORDER': ['PUBLIC PEACE VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER', 'PUBLIC INDECENCY', 'INTIMIDATION', 'STALKING'],
    'LIQOUR AND GAMBLING': ['LIQUOR LAW VIOLATION', 'GAMBLING', 'OBSCENITY', 'CONCEALED CARRY LICENSE VIOLATION'],
    'MISCELLANEOUS': ['OTHER OFFENSE', 'NON-CRIMINAL',
                      'NON-CRIMINAL (SUBJECT SPECIFIED)', 'RITUALISM', 'HUMAN TRAFFICKING']
}

# Function to map the primary type to a category
def map_category(primary_type):
    for category, types in crime_mapping.items():
        if primary_type in types:
            return category
    return 'Other'  # Default category for unmatched types

# Apply the mapping function to create a new column
df['Crime Type'] = df['Primary Type'].apply(map_category)

df.head()
# Out:
#                   ID Case Number                 Block  \
# Date
# 2018-01-01  13230310    JG447808   041XX N ASHLAND AVE
# 2018-01-01  13235163    JG453401     027XX N MANGO AVE
# 2018-01-01  11848137    JC457303  081XX S EBERHART AVE
# 2018-01-01  11768997    JC362338   001XX N ASHLAND AVE
# 2018-01-01  12057588    JD240441     048XX N AVERS AVE
#
#                           Primary Type  \
# Date
# 2018-01-01          DECEPTIVE PRACTICE
# 2018-01-01  OFFENSE INVOLVING CHILDREN
# 2018-01-01     CRIMINAL SEXUAL ASSAULT
# 2018-01-01                 SEX OFFENSE
# 2018-01-01  OFFENSE INVOLVING CHILDREN
#
#                                                   Description  \
# Date
# 2018-01-01                FINANCIAL IDENTITY THEFT OVER $ 300
# 2018-01-01  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 2018-01-01                                 AGGRAVATED - OTHER
# 2018-01-01                          AGG CRIMINAL SEXUAL ABUSE
# 2018-01-01             CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
#
#            Location Description  Arrest  Domestic  Beat  District  Ward  \
# Date
# 2018-01-01            APARTMENT       0         0  1912        19  47.0
# 2018-01-01            RESIDENCE       0         1  2514        25  30.0
# 2018-01-01            RESIDENCE       1         0   631         6   6.0
# 2018-01-01            RESIDENCE       0         1  1224        12  27.0
# 2018-01-01            APARTMENT       0         1  1712        17  35.0
#
#             Community Area  Year        date      time  Weekday  Month  \
# Date
# 2018-01-01             6.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            19.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            44.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            28.0  2018  2018-01-01  00:00:00        0      1
# 2018-01-01            14.0  2018  2018-01-01  00:00:00        0      1
#
#                             Crime Type
# Date
# 2018-01-01          DECEPTIVE PRACTICE
# 2018-01-01  OFFENSE INVOLVING CHILDREN
# 2018-01-01                    VIOLENCE
# 2018-01-01                 SEX OFFENSE
# 2018-01-01  OFFENSE INVOLVING CHILDREN

# %%
crimes_count_date = df.pivot_table('ID', aggfunc=np.size, columns='Crime Type', index=df.index, fill_value=0)
crimes_count_date
# Out:
# Crime Type           DECEPTIVE PRACTICE  DRUGS RELATED  LIQOUR AND GAMBLING  \
# Date
# 2018-01-01 00:00:00                  36              0                    0
# 2018-01-01 00:01:00                   9              0                    1
# 2018-01-01 00:05:00                   0              0                    0
# 2018-01-01 00:08:00                   0              0                    0
# 2018-01-01 00:09:00                   0              0                    0
# ...                                 ...            ...                  ...
# 2023-01-01 23:25:00                   0              0                    0
# 2023-01-01 23:30:00                   0              1                    0
# 2023-01-01 23:33:00                   0              0                    0
# 2023-01-01 23:49:00                   0              0                    0
# 2023-01-01 23:59:00                   0              0                    0
#
# Crime Type           MISCELLANEOUS  OFFENSE INVOLVING CHILDREN  \
# Date
# 2018-01-01 00:00:00              8                          40
# 2018-01-01 00:01:00              3                          74
# 2018-01-01 00:05:00              0                           1
# 2018-01-01 00:08:00              0                           0
# 2018-01-01 00:09:00              0                           0
# ...                            ...                         ...
# 2023-01-01 23:25:00              0                           0
# 2023-01-01 23:30:00              0                           0
# 2023-01-01 23:33:00              0                           0
# 2023-01-01 23:49:00              1                           0
# 2023-01-01 23:59:00              0                           0
#
# Crime Type           PROPERTY DAMAGE  PUBLIC ORDER  SEX OFFENSE  THEFT  \
# Date
# 2018-01-01 00:00:00                4             0           18     12
# 2018-01-01 00:01:00                5             0           19      9
# 2018-01-01 00:05:00                1             0            0      0
# 2018-01-01 00:08:00                1             0            0      0
# 2018-01-01 00:09:00                0             0            0      0
# ...                              ...           ...          ...    ...
# 2023-01-01 23:25:00                0             0            0      0
# 2023-01-01 23:30:00                0             0            0      0
# 2023-01-01 23:33:00                0             1            0      0
# 2023-01-01 23:49:00                0             0            0      1
# 2023-01-01 23:59:00                0             0            0      0
#
# Crime Type           TRESPASSING  VIOLENCE  WEAPONS VIOLATION
# Date
# 2018-01-01 00:00:00            1        21                  0
# 2018-01-01 00:01:00            1         8                  0
# 2018-01-01 00:05:00            0         1                  1
# 2018-01-01 00:08:00            0         0                  0
# 2018-01-01 00:09:00            0         1                  1
# ...                          ...       ...                ...
# 2023-01-01 23:25:00            0         0                  1
# 2023-01-01 23:30:00            0         5                  0
# 2023-01-01 23:33:00            0         0                  0
# 2023-01-01 23:49:00            0         0                  1
# 2023-01-01 23:59:00            0         1                  0
#
# [576390 rows x 12 columns]

# %%
list_of_location_description = list(df['Location Description'].value_counts().index[20:])
df.loc[df['Location Description'].isin(list_of_location_description), df.columns == 'Location Description'] = 'OTHER'

# %% [markdown]
# ## Times series plots for 12 categories of crimes

# %%
ax = crimes_count_date.rolling(365).sum().plot(figsize=(20, 15), subplots=True, layout=(-1, 4), sharex=False, sharey=False)

# Set X-axis tick labels rotation to 45 degrees for all subplots
if isinstance(ax, np.ndarray):
    for axes_row in ax:
        for a in axes_row:
            a.tick_params(axis='x', rotation=45)
else:
    ax.tick_params(axis='x', rotation=45)

# Display the plot
plt.show()

# %%
crimes_count_date.rolling(365).sum().plot(figsize=(25, 40), subplots=True, layout=(-1, 3), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# ## Distribution of crime numbers with respect to the day of the week

# %%
day = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_mapping = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}

crime_count_by_day = df['Weekday'].map(weekday_mapping).value_counts().reindex(day)
plt.figure(figsize=(7, 4))
sns.barplot(x=crime_count_by_day.values, y=crime_count_by_day.index, palette='Blues_d')
plt.title('Number of Crimes by Day of the Week')
plt.ylabel('Day of the Week')
plt.xlabel('Number of Crimes')

for bar in plt.gca().patches:
    bar.set_height(0.6)
plt.show()

# %% [markdown]
# ## Distribution of crime numbers with respect to month

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


# Create a dictionary to map numeric month values to month names
month_mapping = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
                 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# Map the numeric values to month names using the dictionary
df['Month_1'] = df['Month'].map(month_mapping)


# Count the number of crimes for each month
crime_count_by_month = df['Month_1'].value_counts().reindex(month_order)

# Generate a horizontal bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=crime_count_by_month.values, y=crime_count_by_month.index, palette='Blues_d')

plt.title('Number of Crimes by Month')
plt.xlabel('Number of Crimes')
plt.ylabel('Month')
plt.show()

# %% [markdown]
# ## Drawing countplot showing different types of crimes in descending order

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=df['Crime Type'].value_counts(), y=df['Crime Type'].value_counts().index, palette='Blues_d')
plt.title('Types of Crimes in Descending Order', fontsize = 15)
plt.xlabel('Number of Crimes', fontsize = 15)
plt.ylabel('Types of Crimes', fontsize = 15)
plt.show()

# %% [markdown]
# ## Drawing Countplot showing crime incident Location Description

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=df['Location Description'].value_counts(), y=df['Location Description'].value_counts().index, palette='Blues_d')
plt.title('Location Decription of Crimes in Descending Order', fontsize = 15)
plt.xlabel('Number of Crimes', fontsize = 15)
plt.ylabel('Location Description', fontsize = 15)
plt.show()

# %% [markdown]
# ## Creating different pivot table of dataset for drawing heatmap

# %%
###

weekday_mapping = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
df['Weekday'] = df['Weekday'].map(weekday_mapping)

# Create a list of weekdays in the correct order
correct_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

hour_by_location = df.pivot_table(values = 'ID', index = 'Location Description', columns = df.index.hour, aggfunc = np.size).fillna(0)
hour_by_type     = df.pivot_table(values = 'ID', index = 'Crime Type', columns = df.index.hour, aggfunc = np.size).fillna(0)
hour_by_week     = df.pivot_table(values = 'ID', index = df.index.hour, columns = df.Weekday, aggfunc = np.size).fillna(0)[correct_order]
hour_by_week     = hour_by_week.T

day_by_location  = df.pivot_table(values = 'ID', index = 'Location Description', columns = df.Weekday, aggfunc = np.size).fillna(0)[correct_order]
day_by_type      = df.pivot_table(values = 'ID', index = 'Crime Type', columns = df.Weekday, aggfunc = np.size).fillna(0)[correct_order]
type_by_location = df.pivot_table(values = 'ID', index = 'Location Description', columns = 'Crime Type', aggfunc = np.size).fillna(0)

# %% [markdown]
# ## Function for creating heatmap, doing clustering which makes them look nicer

# %%
from sklearn.cluster import AgglomerativeClustering as AC

def scale_df(df,axis=0):
    '''
    A utility function to scale numerical values (z-scale) to have a mean of zero
    and a unit variance.
    '''
    return (df - df.mean(axis=axis)) / df.std(axis=axis)

def plot_hmap(df, ix=None, cmap='bwr'):
    '''
    A function to plot heatmaps that show temporal patterns
    '''
    if ix is None:
        ix = np.arange(df.shape[0])
    plt.imshow(df.iloc[ix,:], cmap=cmap)
    plt.colorbar(fraction = 0.03)
    plt.yticks(ix, df.index[ix])
    plt.xticks(np.arange(df.shape[1]))
    plt.grid(False)
    plt.show()

def scale_and_plot(df, cmap = 'bwr', ix = None):
    '''
    A wrapper function to calculate the scaled values within each row of df and plot_hmap
    '''
    df_marginal_scaled = scale_df(df.T).T
    if ix is None:
        ix = AC(4).fit(df_marginal_scaled).labels_.argsort() # a trick to make better heatmaps
    cap = np.min([np.max(df_marginal_scaled.values), np.abs(np.min(df_marginal_scaled.values))])
    df_marginal_scaled = np.clip(df_marginal_scaled, -1*cap, cap)
    plot_hmap(df_marginal_scaled, ix=ix, cmap = cmap)

def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

# %%
# plt.figure(figsize = (30,10))
# sns.clustermap(scale_df(hour_by_type.T).T)

# %% [markdown]
# ## Heatmap showing intensity of different types of Crime according to hour of day

# %%
plt.figure(figsize = (12,12))
plt.title('Heatmap showing intensity of different types of Crime according to hour of day')
scale_and_plot(hour_by_type, 'Purples')

# %% [markdown]
# ## Heatmap showing intensity of Crime at particular location according to hour of day

# %%
plt.figure(figsize = (10, 15))
plt.title('Heatmap showing intensity of Crime at particular location according to hour of day')
scale_and_plot(hour_by_location, 'bwr')

# %% [markdown]
# ## Heatmap showing intensity of Crime at particular day according to hour of day

# %%
plt.figure(figsize = (12, 7))
plt.title("Heatmap showing intensity of Crime at particular day according to hour of day")
scale_and_plot(hour_by_week, 'Spectral')

# %% [markdown]
# ## Heatmap showing intensity of Crime at different locations according to day of week

# %%
plt.figure(figsize = (4, 8))
plt.title('Heatmap showing intensity of Crime at different locations according to day of week')
scale_and_plot(day_by_location, 'Greens')

# %% [markdown]
# ## Heatmap showing intensity of different types of Crimes according to day of week

# %%
plt.figure(figsize = (4,8))
plt.title("Heatmap showing intensity of different types of Crimes according to day of week")
scale_and_plot(day_by_type, 'Blues')

# %% [markdown]
# ## Heatmap showing intensity of different types of Crimes according to different locations

# %%
df = normalize(type_by_location)
ix = AC(3).fit(df.T).labels_.argsort() # a trick to make better heatmaps
plt.figure(figsize=(10, 15))
plt.imshow(df.T.iloc[ix,:], cmap='PuBuGn')#Reds
plt.colorbar(fraction=0.03)
plt.xticks(np.arange(df.shape[0]), df.index, rotation='vertical')
plt.yticks(np.arange(df.shape[1]), df.columns)
plt.title('Normalized location frequency for each crime')
plt.grid(False)
plt.show()
